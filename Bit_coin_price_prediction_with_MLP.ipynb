# %% [markdown]
# <a href="https://colab.research.google.com/github/DavorJordacevic/KERAS-NEURAL-NETWORKS/blob/master/Bit_coin_price_prediction_with_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bit-coin price prediction with Multilayer Perceptrons
# # Keras implementation

# %%
import math
import keras as k
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9b00204c-53cd-48ed-89e2-9468c783c60b" name="files[]" multiple disabled />
#      <output id="result-9b00204c-53cd-48ed-89e2-9468c783c60b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bitcoin.csv to bitcoin.csv
# {u'bitcoin.csv': 'Date,"Close Price"\n"2010-07-18 00:00:00",0.09\n"2010-07-19 00:00:00",0.08\n"2010-07-20 00:00:00",0.07\n"2010-07-21 00:00:00",0.08\n"2010-07-22 00:00:00",0.05\n"2010-07-23 00:00:00",0.06\n"2010-07-24 00:00:00",0.05\n"2010-07-25 00:00:00",0.05\n"2010-07-26 00:00:00",0.06\n"2010-07-27 00:00:00",0.06\n"2010-07-28 00:00:00",0.06\n"2010-07-29 00:00:00",0.07\n"2010-07-30 00:00:00",0.06\n"2010-07-31 00:00:00",0.07\n"2010-08-01 00:00:00",0.06\n"2010-08-02 00:00:00",0.06\n"2010-08-03 00:00:00",0.06\n"2010-08-04 00:00:00",0.06\n"2010-08-05 00:00:00",0.06\n"2010-08-06 00:00:00",0.06\n"2010-08-07 00:00:00",0.06\n"2010-08-08 00:00:00",0.06\n"2010-08-09 00:00:00",0.07\n"2010-08-10 00:00:00",0.07\n"2010-08-11 00:00:00",0.07\n"2010-08-12 00:00:00",0.07\n"2010-08-13 00:00:00",0.06\n"2010-08-14 00:00:00",0.07\n"2010-08-15 00:00:00",0.07\n"2010-08-16 00:00:00",0.07\n"2010-08-17 00:00:00",0.07\n"2010-08-18 00:00:00",0.07\n"2010-08-19 00:00:00",0.07\n"2010-08-20 00:00:00",0.07\n"2010-08-21 00:00:00",0.07\n"2010-08-22 00:00:00",0.07\n"2010-08-23 00:00:00",0.06\n"2010-08-24 00:00:00",0.06\n"2010-08-25 00:00:00",0.06\n"2010-08-26 00:00:00",0.06\n"2010-08-27 00:00:00",0.06\n"2010-08-28 00:00:00",0.06\n"2010-08-29 00:00:00",0.06\n"2010-08-30 00:00:00",0.06\n"2010-08-31 00:00:00",0.06\n"2010-09-01 00:00:00",0.06\n"2010-09-02 00:00:00",0.06\n"2010-09-03 00:00:00",0.06\n"2010-09-04 00:00:00",0.06\n"2010-09-05 00:00:00",0.06\n"2010-09-06 00:00:00",0.06\n"2010-09-07 00:00:00",0.06\n"2010-09-08 00:00:00",0.06\n"2010-09-09 00:00:00",0.06\n"2010-09-10 00:00:00",0.06\n"2010-09-11 00:00:00",0.06\n"2010-09-12 00:00:00",0.06\n"2010-09-13 00:00:00",0.06\n"2010-09-14 00:00:00",0.06\n"2010-09-15 00:00:00",0.06\n"2010-09-16 00:00:00",0.06\n"2010-09-17 00:00:00",0.06\n"2010-09-18 00:00:00",0.06\n"2010-09-19 00:00:00",0.06\n"2010-09-20 00:00:00",0.06\n"2010-09-21 00:00:00",0.06\n"2010-09-22 00:00:00",0.06\n"2010-09-23 00:00:00",0.06\n"2010-09-24 00:00:00",0.06\n"2010-09-25 00:00:00",0.06\n"2010-09-26 00:
# 2695  2017-12-03 00:00:00     11180.89
# 2696  2017-12-04 19:51:00     11212.66

# %%
print(data.head()['Date'])
# Out:
# 0    2010-07-18 00:00:00
# 1    2010-07-19 00:00:00
# 2    2010-07-20 00:00:00
# 3    2010-07-21 00:00:00
# 4    2010-07-22 00:00:00
# Name: Date, dtype: object

# %%
print(data.head()['Close Price'])
# Out:
# 0    0.09
# 1    0.08
# 2    0.07
# 3    0.08
# 4    0.05
# Name: Close Price, dtype: float64

# %%
dataset = data['Close Price'].values
dataset = dataset.astype('float32')
dataset = dataset.reshape(dataset.shape[0],1)

# %%
dataset.shape
# Out:
# (2699, 1)

# %%
plt.plot(dataset)

# %%
from keras.models import Sequential
from keras.layers import Dense
# fix random seed for reproducibilty
np.random.seed(7)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size  = len(dataset)- train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train),len(test))
# Out:
# (1808, 891)

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset,look_back=1):
  dataX,dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return np.array(dataX),np.array(dataY)

# %%
# reshape into X=t Y=t+1
look_back = 1
trainX, trainY = create_dataset(train,look_back)
testX, testY   = create_dataset(test,look_back)

# %%
# create and fit Multilayer Perceptron model
def create_model():
  model = Sequential()
  model.add(Dense(8,input_dim=look_back,activation='relu'))
  model.add(Dense(1))
  model.compile(loss='mse',optimizer='adam')
  return model

# %%
model = create_model()
model.fit(trainX,trainY,
         epochs = 20,
         batch_size=2,
         verbose=2)
# Out:
# Epoch 1/20
#  - 1s - loss: 35050.1002
# Epoch 2/20
#  - 1s - loss: 344.4877
# Epoch 3/20
#  - 1s - loss: 339.3380
# Epoch 4/20
#  - 1s - loss: 338.1183
# Epoch 5/20
#  - 1s - loss: 341.4807
# Epoch 6/20
#  - 1s - loss: 339.1920
# Epoch 7/20
#  - 1s - loss: 348.9211
# Epoch 8/20
#  - 1s - loss: 352.7788
# Epoch 9/20
#  - 1s - loss: 337.1897
# Epoch 10/20
#  - 1s - loss: 347.4379
# Epoch 11/20
#  - 1s - loss: 352.3703
# Epoch 12/20
#  - 1s - loss: 346.6474
# Epoch 13/20
#  - 1s - loss: 327.8844
# Epoch 14/20
#  - 1s - loss: 346.5268
# Epoch 15/20
#  - 1s - loss: 341.2554
# Epoch 16/20
#  - 1s - loss: 346.3857
# Epoch 17/20
#  - 1s - loss: 344.9077
# Epoch 18/20
#  - 1s - loss: 343.1219
# Epoch 19/20
#  - 1s - loss: 349.6124
# Epoch 20/20
#  - 1s - loss: 347.2041

# %%
# Estimate model performance
trainScore = model.evaluate(trainX,trainY,verbose=0)
print('Train score: %.2f MSe (%.2f RMSE)' % (trainScore,math.sqrt(trainScore)))
testScore  = model.evaluate(testX,testY,verbose=0)
print('Test score: %.2f MSE (%.2f RMSE)' % (testScore,math.sqrt(testScore)))
# Out:
# Train score: 330.14 MSe (18.17 RMSE)
# Test score: nan MSE (nan RMSE)

# %%
# generate predictions for traingin
trainPredict = model.predict(trainX)
testPredict  = model.predict(testX)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back,:] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1,:] = testPredict

# %%
# plot baselne and predictions
plt.plot(dataset,'b')
plt.plot(trainPredictPlot,'r')
plt.plot(testPredictPlot,'g')

# %%
plt.subplot(211)
plt.plot(dataset)
plt.subplot(212)
plt.plot(testPredictPlot)
