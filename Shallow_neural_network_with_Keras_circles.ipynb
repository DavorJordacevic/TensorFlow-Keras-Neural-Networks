# %% [markdown]
# <a href="https://colab.research.google.com/github/DavorJordacevic/NEURAL-NETWORKS-/blob/master/Shallow_neural_network_with_Keras_circles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shallow_neural_network_with_Keras

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from mpl_toolkits import mplot3d
from matplotlib import cm
from keras.models import Sequential
from keras.layers import Dense
from keras import backend as K
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import adam
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# %%
# generate two datasets
X,y = make_circles(n_samples = 3000, noise = 0.08, factor=0.3)
print(X.shape)
print(y.shape)
print(type(X))
print(type(y))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# Out:
# (3000, 2)
# (3000,)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
X0 = [X[i,:] for i in range(len(y)) if y[i] == 0] # returns the row where the corresponding label is 0
X1 = [X[i,:] for i in range(len(y)) if y[i] == 1] # returns the row where the corresponding label is 1

            
X0_np = np.array(X0) # convert it into an array
X1_np = np.array(X1) 

X0_train = X0_np[:1000,:].T # picked the first 1000 samples in the second axis
X0_test = X0_np[1000:,:].T # picked the remaining 500 samples in the second axis

X1_train = X1_np[:1000,:].T  # picked the first 1000 samples in the second axis
X1_test = X1_np[1000:,:].T # picked the remaining 500 samples in the second axis

X_train = np.hstack([X0_train,X1_train]).T # all training examples
y_train=np.zeros((1,2000))
y_train[0, 1000:] = 1

X_test = np.hstack([X0_test,X1_test]).T # all test examples
y_test=np.zeros((1,1000))
y_test[0, 500:] = 1

# %%
plt.figure(figsize=(12,8))
plt.scatter(X0_train[0,:],X0_train[1,:], color = 'b', label = 'class 0 train')
plt.scatter(X1_train[0,:],X1_train[1,:], color = 'r',  label = 'class 1 train')
plt.scatter(X0_test[0,:],X0_test[1,:], color = 'LightBlue', label = 'class 0 test')
plt.scatter(X1_test[0,:],X1_test[1,:], color = 'Orange', label = 'class 1 test')
plt.xlabel('feature1')
plt.ylabel('feature2')
plt.legend()
plt.axis('equal')
plt.show()

# %%
print('x_train:\t{}' .format(X_train.shape))
print('y_train:\t{}' .format(y_train.shape))
print('x_test:\t\t{}'.format(X_test.shape))
print('y_test:\t\t{}'.format(y_test.shape))
# Out:
# x_train:	(2000, 2)
# y_train:	(1, 2000)
# x_test:		(1000, 2)
# y_test:		(1, 1000)

# %%
# Hyper-parameters
training_epochs = 400 # Total number of training epochs
learning_rate = 0.03 # The learning rate

# %%
# create model
def create_model():
  model = Sequential()
  # Input layer
  model.add(Dense(6, input_dim=2, kernel_initializer='normal', activation='relu'))
  # Output layer
  model.add(Dense(y_train.T.shape[1], activation='sigmoid'))
 
  # Compile model
  model.compile(loss='binary_crossentropy', optimizer=adam(learning_rate), metrics=['accuracy'])
  return model
model = create_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 6)                 18
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model.fit(
 X_train, y_train.T,
 epochs= training_epochs,
 batch_size = 516,
 validation_data = (X_test, y_test.T)
)
# Out:
# Train on 2000 samples, validate on 1000 samples
# Epoch 1/400
# 2000/2000 [==============================] - 1s 277us/step - loss: 0.6878 - acc: 0.4885 - val_loss: 0.6751 - val_acc: 0.5000
# Epoch 2/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.6720 - acc: 0.5935 - val_loss: 0.6572 - val_acc: 0.6420
# Epoch 3/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.6546 - acc: 0.6175 - val_loss: 0.6354 - val_acc: 0.6840
# Epoch 4/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.6336 - acc: 0.7095 - val_loss: 0.6108 - val_acc: 0.7810
# Epoch 5/400
# 2000/2000 [==============================] - 0s 5us/step - loss: 0.6094 - acc: 0.7705 - val_loss: 0.5837 - val_acc: 0.8210
# Epoch 6/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.5834 - acc: 0.8020 - val_loss: 0.5553 - val_acc: 0.8470
# Epoch 7/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.5559 - acc: 0.8220 - val_loss: 0.5273 - val_acc: 0.8540
# Epoch 8/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.5283 - acc: 0.8350 - val_loss: 0.4996 - val_acc: 0.8590
# Epoch 9/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.5021 - acc: 0.8430 - val_loss: 0.4736 - val_acc: 0.8570
# Epoch 10/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.4776 - acc: 0.8380 - val_loss: 0.4512 - val_acc: 0.8500
# Epoch 11/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.4564 - acc: 0.8350 - val_loss: 0.4322 - val_acc: 0.8450
# Epoch 12/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.4383 - acc: 0.8395 - val_loss: 0.4143 - val_acc: 0.8520
# Epoch 13/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.4235 - acc: 0.8385 - val_loss: 0.4003 - val_acc: 0.8550
# Epoch 14/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.4123 - acc: 0.8430 - val_loss: 0.3902 - val_acc: 0.8500
# Epoch 15/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.4025 - acc: 0.8425 - val_loss: 0.3809 - val_acc: 0.8530
# Epoch 16/400
# 2000/2000 [==============================] - 0s 5us/step - loss: 0.3949 - acc: 0.8415 - val_loss: 0.3739 - val_acc: 0.8520
# Epoch 17/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.3889 - acc: 0.8395 - val_loss: 0.3680 - val_acc: 0.8530
# Epoch 18/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.3828 - acc: 0.8400 - val_loss: 0.3623 - val_acc: 0.8550
# Epoch 19/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.3763 - acc: 0.8445 - val_loss: 0.3540 - val_acc: 0.8530
# Epoch 20/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.3667 - acc: 0.8430 - val_loss: 0.3405 - val_acc: 0.8570
# Epoch 21/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.3512 - acc: 0.8525 - val_loss: 0.3206 - val_acc: 0.8820
# Epoch 22/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.3273 - acc: 0.8685 - val_loss: 0.2959 - val_acc: 0.9000
# Epoch 23/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.2996 - acc: 0.8845 - val_loss: 0.2665 - val_acc: 0.9160
# Epoch 24/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.2679 - acc: 0.9060 - val_loss: 0.2361 - val_acc: 0.9280
# Epoch 25/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.2339 - acc: 0.9240 - val_loss: 0.2044 - val_acc: 0.9500
# Epoch 26/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.2000 - acc: 0.9510 - val_loss: 0.1744 - val_acc: 0.9720
# Epoch 27/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.1694 - acc: 0.9740 - val_loss: 0.1486 - val_acc: 0.9860
# Epoch 28/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.1440 - acc: 0.9840 - val_loss: 0.1263 - val_acc: 0.9920
# Epoch 29/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.1221 - acc: 0.9910 - val_loss: 0.1080 - val_acc: 0.9950
# Epoch 30/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.1045 - acc: 0.9950 - val_loss: 0.0937 - val_acc: 0.9970
# Epoch 31/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0907 - acc: 0.9965 - val_loss: 0.0826 - val_acc: 0.9990
# Epoch 32/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0797 - acc: 0.9980 - val_loss: 0.0737 - val_acc: 0.9990
# Epoch 33/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0711 - acc: 0.9990 - val_loss: 0.0669 - val_acc: 0.9990
# Epoch 34/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0645 - acc: 0.9990 - val_loss: 0.0616 - val_acc: 1.0000
# Epoch 35/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0593 - acc: 0.9990 - val_loss: 0.0573 - val_acc: 1.0000
# Epoch 36/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0552 - acc: 0.9990 - val_loss: 0.0537 - val_acc: 1.0000
# Epoch 37/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0518 - acc: 0.9990 - val_loss: 0.0506 - val_acc: 1.0000
# Epoch 38/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0488 - acc: 0.9990 - val_loss: 0.0483 - val_acc: 1.0000
# Epoch 39/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0462 - acc: 0.9990 - val_loss: 0.0460 - val_acc: 1.0000
# Epoch 40/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0439 - acc: 0.9990 - val_loss: 0.0437 - val_acc: 1.0000
# Epoch 41/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0418 - acc: 0.9990 - val_loss: 0.0416 - val_acc: 1.0000
# Epoch 42/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0399 - acc: 0.9990 - val_loss: 0.0398 - val_acc: 1.0000
# Epoch 43/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0382 - acc: 0.9990 - val_loss: 0.0382 - val_acc: 1.0000
# Epoch 44/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0366 - acc: 0.9990 - val_loss: 0.0367 - val_acc: 1.0000
# Epoch 45/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0352 - acc: 0.9990 - val_loss: 0.0353 - val_acc: 1.0000
# Epoch 46/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0338 - acc: 0.9990 - val_loss: 0.0341 - val_acc: 1.0000
# Epoch 47/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0326 - acc: 0.9990 - val_loss: 0.0329 - val_acc: 1.0000
# Epoch 48/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0315 - acc: 0.9990 - val_loss: 0.0318 - val_acc: 1.0000
# Epoch 49/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0305 - acc: 0.9990 - val_loss: 0.0307 - val_acc: 1.0000
# Epoch 50/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0295 - acc: 0.9990 - val_loss: 0.0297 - val_acc: 1.0000
# Epoch 51/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0286 - acc: 0.9990 - val_loss: 0.0288 - val_acc: 1.0000
# Epoch 52/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0277 - acc: 0.9990 - val_loss: 0.0280 - val_acc: 1.0000
# Epoch 53/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0269 - acc: 0.9990 - val_loss: 0.0273 - val_acc: 1.0000
# Epoch 54/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0262 - acc: 0.9990 - val_loss: 0.0265 - val_acc: 1.0000
# Epoch 55/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0255 - acc: 0.9990 - val_loss: 0.0258 - val_acc: 1.0000
# Epoch 56/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0248 - acc: 0.9990 - val_loss: 0.0251 - val_acc: 1.0000
# Epoch 57/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0241 - acc: 0.9990 - val_loss: 0.0245 - val_acc: 1.0000
# Epoch 58/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0235 - acc: 0.9990 - val_loss: 0.0239 - val_acc: 1.0000
# Epoch 59/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0230 - acc: 0.9990 - val_loss: 0.0234 - val_acc: 1.0000
# Epoch 60/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0224 - acc: 0.9990 - val_loss: 0.0229 - val_acc: 1.0000
# Epoch 61/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0219 - acc: 0.9990 - val_loss: 0.0223 - val_acc: 1.0000
# Epoch 62/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0214 - acc: 0.9990 - val_loss: 0.0217 - val_acc: 1.0000
# Epoch 63/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0210 - acc: 0.9990 - val_loss: 0.0213 - val_acc: 1.0000
# Epoch 64/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0205 - acc: 0.9990 - val_loss: 0.0209 - val_acc: 1.0000
# Epoch 65/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0201 - acc: 0.9990 - val_loss: 0.0206 - val_acc: 1.0000
# Epoch 66/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0197 - acc: 0.9990 - val_loss: 0.0201 - val_acc: 1.0000
# Epoch 67/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0193 - acc: 0.9990 - val_loss: 0.0198 - val_acc: 1.0000
# Epoch 68/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0189 - acc: 0.9990 - val_loss: 0.0193 - val_acc: 1.0000
# Epoch 69/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0186 - acc: 0.9990 - val_loss: 0.0190 - val_acc: 1.0000
# Epoch 70/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0182 - acc: 0.9990 - val_loss: 0.0186 - val_acc: 1.0000
# Epoch 71/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0179 - acc: 0.9990 - val_loss: 0.0183 - val_acc: 1.0000
# Epoch 72/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0176 - acc: 0.9990 - val_loss: 0.0180 - val_acc: 1.0000
# Epoch 73/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0173 - acc: 0.9990 - val_loss: 0.0177 - val_acc: 1.0000
# Epoch 74/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0170 - acc: 0.9990 - val_loss: 0.0174 - val_acc: 1.0000
# Epoch 75/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0167 - acc: 0.9990 - val_loss: 0.0171 - val_acc: 1.0000
# Epoch 76/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0164 - acc: 0.9990 - val_loss: 0.0168 - val_acc: 1.0000
# Epoch 77/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0162 - acc: 0.9990 - val_loss: 0.0165 - val_acc: 1.0000
# Epoch 78/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0159 - acc: 0.9990 - val_loss: 0.0163 - val_acc: 1.0000
# Epoch 79/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0157 - acc: 0.9990 - val_loss: 0.0162 - val_acc: 1.0000
# Epoch 80/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0154 - acc: 0.9990 - val_loss: 0.0160 - val_acc: 1.0000
# Epoch 81/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0152 - acc: 0.9990 - val_loss: 0.0156 - val_acc: 1.0000
# Epoch 82/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0150 - acc: 0.9990 - val_loss: 0.0153 - val_acc: 1.0000
# Epoch 83/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0147 - acc: 0.9990 - val_loss: 0.0150 - val_acc: 1.0000
# Epoch 84/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0145 - acc: 0.9990 - val_loss: 0.0148 - val_acc: 1.0000
# Epoch 85/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0143 - acc: 0.9990 - val_loss: 0.0147 - val_acc: 1.0000
# Epoch 86/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0142 - acc: 0.9995 - val_loss: 0.0146 - val_acc: 1.0000
# Epoch 87/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0139 - acc: 0.9995 - val_loss: 0.0144 - val_acc: 1.0000
# Epoch 88/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0138 - acc: 0.9990 - val_loss: 0.0141 - val_acc: 1.0000
# Epoch 89/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0136 - acc: 0.9990 - val_loss: 0.0139 - val_acc: 1.0000
# Epoch 90/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0134 - acc: 0.9990 - val_loss: 0.0138 - val_acc: 1.0000
# Epoch 91/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0132 - acc: 0.9990 - val_loss: 0.0136 - val_acc: 1.0000
# Epoch 92/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0131 - acc: 0.9990 - val_loss: 0.0134 - val_acc: 1.0000
# Epoch 93/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0129 - acc: 0.9990 - val_loss: 0.0132 - val_acc: 1.0000
# Epoch 94/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0128 - acc: 0.9990 - val_loss: 0.0131 - val_acc: 1.0000
# Epoch 95/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0126 - acc: 0.9990 - val_loss: 0.0129 - val_acc: 1.0000
# Epoch 96/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0125 - acc: 0.9990 - val_loss: 0.0128 - val_acc: 1.0000
# Epoch 97/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0123 - acc: 0.9990 - val_loss: 0.0126 - val_acc: 1.0000
# Epoch 98/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0122 - acc: 0.9990 - val_loss: 0.0125 - val_acc: 1.0000
# Epoch 99/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0120 - acc: 0.9990 - val_loss: 0.0124 - val_acc: 1.0000
# Epoch 100/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0119 - acc: 0.9990 - val_loss: 0.0122 - val_acc: 1.0000
# Epoch 101/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0118 - acc: 0.9990 - val_loss: 0.0121 - val_acc: 1.0000
# Epoch 102/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0116 - acc: 0.9990 - val_loss: 0.0119 - val_acc: 1.0000
# Epoch 103/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0116 - acc: 0.9990 - val_loss: 0.0117 - val_acc: 1.0000
# Epoch 104/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0114 - acc: 0.9990 - val_loss: 0.0117 - val_acc: 1.0000
# Epoch 105/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0113 - acc: 0.9990 - val_loss: 0.0116 - val_acc: 1.0000
# Epoch 106/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0112 - acc: 0.9990 - val_loss: 0.0114 - val_acc: 1.0000
# Epoch 107/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0110 - acc: 0.9990 - val_loss: 0.0113 - val_acc: 1.0000
# Epoch 108/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0109 - acc: 0.9990 - val_loss: 0.0112 - val_acc: 1.0000
# Epoch 109/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0108 - acc: 0.9990 - val_loss: 0.0111 - val_acc: 1.0000
# Epoch 110/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0107 - acc: 0.9990 - val_loss: 0.0110 - val_acc: 1.0000
# Epoch 111/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0106 - acc: 0.9990 - val_loss: 0.0109 - val_acc: 1.0000
# Epoch 112/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0105 - acc: 0.9990 - val_loss: 0.0107 - val_acc: 1.0000
# Epoch 113/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0104 - acc: 0.9990 - val_loss: 0.0106 - val_acc: 1.0000
# Epoch 114/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0103 - acc: 0.9990 - val_loss: 0.0105 - val_acc: 1.0000
# Epoch 115/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0103 - acc: 0.9990 - val_loss: 0.0104 - val_acc: 1.0000
# Epoch 116/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0101 - acc: 0.9990 - val_loss: 0.0104 - val_acc: 1.0000
# Epoch 117/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0101 - acc: 0.9990 - val_loss: 0.0103 - val_acc: 1.0000
# Epoch 118/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0100 - acc: 0.9995 - val_loss: 0.0102 - val_acc: 1.0000
# Epoch 119/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0099 - acc: 0.9995 - val_loss: 0.0101 - val_acc: 1.0000
# Epoch 120/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0098 - acc: 0.9995 - val_loss: 0.0100 - val_acc: 1.0000
# Epoch 121/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0097 - acc: 0.9990 - val_loss: 0.0098 - val_acc: 1.0000
# Epoch 122/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0097 - acc: 0.9990 - val_loss: 0.0098 - val_acc: 1.0000
# Epoch 123/400
# 2000/2000 [==============================] - 0s 5us/step - loss: 0.0095 - acc: 0.9990 - val_loss: 0.0098 - val_acc: 1.0000
# Epoch 124/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0095 - acc: 0.9990 - val_loss: 0.0097 - val_acc: 1.0000
# Epoch 125/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0094 - acc: 0.9995 - val_loss: 0.0096 - val_acc: 1.0000
# Epoch 126/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0093 - acc: 0.9990 - val_loss: 0.0095 - val_acc: 1.0000
# Epoch 127/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0093 - acc: 0.9990 - val_loss: 0.0094 - val_acc: 1.0000
# Epoch 128/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0092 - acc: 0.9990 - val_loss: 0.0093 - val_acc: 1.0000
# Epoch 129/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0091 - acc: 0.9990 - val_loss: 0.0092 - val_acc: 1.0000
# Epoch 130/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0090 - acc: 0.9990 - val_loss: 0.0092 - val_acc: 1.0000
# Epoch 131/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0089 - acc: 0.9995 - val_loss: 0.0092 - val_acc: 1.0000
# Epoch 132/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0089 - acc: 0.9990 - val_loss: 0.0090 - val_acc: 1.0000
# Epoch 133/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0088 - acc: 0.9990 - val_loss: 0.0090 - val_acc: 1.0000
# Epoch 134/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0087 - acc: 0.9990 - val_loss: 0.0089 - val_acc: 1.0000
# Epoch 135/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0087 - acc: 0.9995 - val_loss: 0.0088 - val_acc: 1.0000
# Epoch 136/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0086 - acc: 0.9995 - val_loss: 0.0087 - val_acc: 1.0000
# Epoch 137/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0086 - acc: 0.9990 - val_loss: 0.0087 - val_acc: 1.0000
# Epoch 138/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0085 - acc: 0.9990 - val_loss: 0.0086 - val_acc: 1.0000
# Epoch 139/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0084 - acc: 0.9990 - val_loss: 0.0085 - val_acc: 1.0000
# Epoch 140/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0084 - acc: 0.9990 - val_loss: 0.0085 - val_acc: 1.0000
# Epoch 141/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0083 - acc: 0.9995 - val_loss: 0.0085 - val_acc: 1.0000
# Epoch 142/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0083 - acc: 0.9990 - val_loss: 0.0084 - val_acc: 1.0000
# Epoch 143/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0082 - acc: 0.9990 - val_loss: 0.0083 - val_acc: 1.0000
# Epoch 144/400
# 2000/2000 [==============================] - 0s 11us/step - loss: 0.0081 - acc: 0.9990 - val_loss: 0.0082 - val_acc: 1.0000
# Epoch 145/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0081 - acc: 0.9990 - val_loss: 0.0082 - val_acc: 1.0000
# Epoch 146/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0080 - acc: 0.9990 - val_loss: 0.0081 - val_acc: 1.0000
# Epoch 147/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0080 - acc: 0.9990 - val_loss: 0.0081 - val_acc: 1.0000
# Epoch 148/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0079 - acc: 0.9995 - val_loss: 0.0080 - val_acc: 1.0000
# Epoch 149/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0079 - acc: 0.9995 - val_loss: 0.0080 - val_acc: 1.0000
# Epoch 150/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0078 - acc: 0.9995 - val_loss: 0.0080 - val_acc: 1.0000
# Epoch 151/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0078 - acc: 0.9995 - val_loss: 0.0079 - val_acc: 1.0000
# Epoch 152/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0077 - acc: 0.9995 - val_loss: 0.0078 - val_acc: 1.0000
# Epoch 153/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0077 - acc: 0.9990 - val_loss: 0.0077 - val_acc: 1.0000
# Epoch 154/400
# 2000/2000 [==============================] - 0s 5us/step - loss: 0.0076 - acc: 0.9990 - val_loss: 0.0077 - val_acc: 1.0000
# Epoch 155/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0076 - acc: 0.9990 - val_loss: 0.0077 - val_acc: 1.0000
# Epoch 156/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0075 - acc: 0.9990 - val_loss: 0.0076 - val_acc: 1.0000
# Epoch 157/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0075 - acc: 0.9995 - val_loss: 0.0076 - val_acc: 1.0000
# Epoch 158/400
# 2000/2000 [==============================] - 0s 5us/step - loss: 0.0074 - acc: 0.9995 - val_loss: 0.0075 - val_acc: 1.0000
# Epoch 159/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0074 - acc: 0.9995 - val_loss: 0.0075 - val_acc: 1.0000
# Epoch 160/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0074 - acc: 0.9995 - val_loss: 0.0075 - val_acc: 1.0000
# Epoch 161/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0073 - acc: 0.9990 - val_loss: 0.0073 - val_acc: 1.0000
# Epoch 162/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0073 - acc: 0.9990 - val_loss: 0.0073 - val_acc: 1.0000
# Epoch 163/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0072 - acc: 0.9990 - val_loss: 0.0073 - val_acc: 1.0000
# Epoch 164/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0072 - acc: 0.9995 - val_loss: 0.0072 - val_acc: 1.0000
# Epoch 165/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0071 - acc: 0.9995 - val_loss: 0.0072 - val_acc: 1.0000
# Epoch 166/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0071 - acc: 0.9995 - val_loss: 0.0072 - val_acc: 1.0000
# Epoch 167/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0071 - acc: 0.9995 - val_loss: 0.0071 - val_acc: 1.0000
# Epoch 168/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0070 - acc: 0.9990 - val_loss: 0.0070 - val_acc: 1.0000
# Epoch 169/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0070 - acc: 0.9990 - val_loss: 0.0069 - val_acc: 1.0000
# Epoch 170/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0069 - acc: 0.9990 - val_loss: 0.0069 - val_acc: 1.0000
# Epoch 171/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0069 - acc: 0.9990 - val_loss: 0.0070 - val_acc: 1.0000
# Epoch 172/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0069 - acc: 0.9995 - val_loss: 0.0070 - val_acc: 1.0000
# Epoch 173/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0068 - acc: 0.9995 - val_loss: 0.0070 - val_acc: 1.0000
# Epoch 174/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0068 - acc: 0.9995 - val_loss: 0.0068 - val_acc: 1.0000
# Epoch 175/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0067 - acc: 0.9990 - val_loss: 0.0067 - val_acc: 1.0000
# Epoch 176/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0067 - acc: 0.9990 - val_loss: 0.0067 - val_acc: 1.0000
# Epoch 177/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0067 - acc: 0.9995 - val_loss: 0.0067 - val_acc: 1.0000
# Epoch 178/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0067 - acc: 0.9995 - val_loss: 0.0067 - val_acc: 1.0000
# Epoch 179/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0066 - acc: 0.9995 - val_loss: 0.0066 - val_acc: 1.0000
# Epoch 180/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0065 - acc: 0.9995 - val_loss: 0.0066 - val_acc: 1.0000
# Epoch 181/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0065 - acc: 0.9995 - val_loss: 0.0065 - val_acc: 1.0000
# Epoch 182/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0065 - acc: 0.9995 - val_loss: 0.0065 - val_acc: 1.0000
# Epoch 183/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0065 - acc: 0.9995 - val_loss: 0.0066 - val_acc: 1.0000
# Epoch 184/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0065 - acc: 0.9995 - val_loss: 0.0066 - val_acc: 1.0000
# Epoch 185/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0064 - acc: 0.9995 - val_loss: 0.0065 - val_acc: 1.0000
# Epoch 186/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0064 - acc: 0.9995 - val_loss: 0.0063 - val_acc: 1.0000
# Epoch 187/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0063 - acc: 0.9990 - val_loss: 0.0062 - val_acc: 1.0000
# Epoch 188/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0063 - acc: 0.9990 - val_loss: 0.0062 - val_acc: 1.0000
# Epoch 189/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0063 - acc: 0.9990 - val_loss: 0.0062 - val_acc: 1.0000
# Epoch 190/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0062 - acc: 0.9995 - val_loss: 0.0063 - val_acc: 1.0000
# Epoch 191/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0062 - acc: 0.9995 - val_loss: 0.0062 - val_acc: 1.0000
# Epoch 192/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0062 - acc: 0.9995 - val_loss: 0.0062 - val_acc: 1.0000
# Epoch 193/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0061 - acc: 0.9995 - val_loss: 0.0061 - val_acc: 1.0000
# Epoch 194/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0061 - acc: 0.9995 - val_loss: 0.0061 - val_acc: 1.0000
# Epoch 195/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0061 - acc: 0.9995 - val_loss: 0.0060 - val_acc: 1.0000
# Epoch 196/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0061 - acc: 0.9995 - val_loss: 0.0060 - val_acc: 1.0000
# Epoch 197/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0060 - acc: 0.9995 - val_loss: 0.0060 - val_acc: 1.0000
# Epoch 198/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0060 - acc: 0.9995 - val_loss: 0.0060 - val_acc: 1.0000
# Epoch 199/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0060 - acc: 0.9995 - val_loss: 0.0061 - val_acc: 1.0000
# Epoch 200/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0060 - acc: 0.9995 - val_loss: 0.0059 - val_acc: 1.0000
# Epoch 201/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0059 - acc: 0.9995 - val_loss: 0.0058 - val_acc: 1.0000
# Epoch 202/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0059 - acc: 0.9995 - val_loss: 0.0058 - val_acc: 1.0000
# Epoch 203/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0058 - acc: 0.9995 - val_loss: 0.0059 - val_acc: 1.0000
# Epoch 204/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0058 - acc: 0.9995 - val_loss: 0.0058 - val_acc: 1.0000
# Epoch 205/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0058 - acc: 0.9995 - val_loss: 0.0058 - val_acc: 1.0000
# Epoch 206/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0058 - acc: 0.9995 - val_loss: 0.0057 - val_acc: 1.0000
# Epoch 207/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0058 - acc: 0.9995 - val_loss: 0.0057 - val_acc: 1.0000
# Epoch 208/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0057 - acc: 0.9995 - val_loss: 0.0057 - val_acc: 1.0000
# Epoch 209/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0057 - acc: 0.9995 - val_loss: 0.0057 - val_acc: 1.0000
# Epoch 210/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0057 - acc: 0.9995 - val_loss: 0.0056 - val_acc: 1.0000
# Epoch 211/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0056 - acc: 0.9995 - val_loss: 0.0056 - val_acc: 1.0000
# Epoch 212/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0056 - acc: 0.9995 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 213/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0056 - acc: 0.9995 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 214/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0056 - acc: 0.9995 - val_loss: 0.0056 - val_acc: 1.0000
# Epoch 215/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0055 - acc: 0.9995 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 216/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0055 - acc: 0.9995 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 217/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0055 - acc: 0.9995 - val_loss: 0.0054 - val_acc: 1.0000
# Epoch 218/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0054 - acc: 0.9995 - val_loss: 0.0054 - val_acc: 1.0000
# Epoch 219/400
# 2000/2000 [==============================] - 0s 11us/step - loss: 0.0055 - acc: 0.9995 - val_loss: 0.0054 - val_acc: 1.0000
# Epoch 220/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0054 - acc: 0.9995 - val_loss: 0.0053 - val_acc: 1.0000
# Epoch 221/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0054 - acc: 0.9995 - val_loss: 0.0054 - val_acc: 1.0000
# Epoch 222/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0054 - acc: 0.9995 - val_loss: 0.0053 - val_acc: 1.0000
# Epoch 223/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0053 - acc: 0.9995 - val_loss: 0.0053 - val_acc: 1.0000
# Epoch 224/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0053 - acc: 0.9995 - val_loss: 0.0053 - val_acc: 1.0000
# Epoch 225/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0053 - acc: 0.9995 - val_loss: 0.0053 - val_acc: 1.0000
# Epoch 226/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0053 - acc: 0.9995 - val_loss: 0.0052 - val_acc: 1.0000
# Epoch 227/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0052 - acc: 0.9995 - val_loss: 0.0052 - val_acc: 1.0000
# Epoch 228/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0052 - acc: 0.9995 - val_loss: 0.0052 - val_acc: 1.0000
# Epoch 229/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0052 - acc: 0.9995 - val_loss: 0.0052 - val_acc: 1.0000
# Epoch 230/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0052 - acc: 0.9995 - val_loss: 0.0053 - val_acc: 1.0000
# Epoch 231/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0052 - acc: 0.9995 - val_loss: 0.0052 - val_acc: 1.0000
# Epoch 232/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0051 - acc: 0.9995 - val_loss: 0.0051 - val_acc: 1.0000
# Epoch 233/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0051 - acc: 0.9995 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 234/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0051 - acc: 0.9995 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 235/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0051 - acc: 0.9995 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 236/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0050 - acc: 0.9995 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 237/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0050 - acc: 0.9995 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 238/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0050 - acc: 0.9995 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 239/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0050 - acc: 0.9995 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 240/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0049 - acc: 0.9995 - val_loss: 0.0049 - val_acc: 1.0000
# Epoch 241/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0050 - acc: 0.9995 - val_loss: 0.0048 - val_acc: 1.0000
# Epoch 242/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0049 - acc: 0.9995 - val_loss: 0.0048 - val_acc: 1.0000
# Epoch 243/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0049 - acc: 0.9995 - val_loss: 0.0049 - val_acc: 1.0000
# Epoch 244/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0049 - acc: 0.9995 - val_loss: 0.0049 - val_acc: 1.0000
# Epoch 245/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0049 - acc: 0.9995 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 246/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0049 - acc: 0.9995 - val_loss: 0.0049 - val_acc: 1.0000
# Epoch 247/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0049 - acc: 0.9995 - val_loss: 0.0047 - val_acc: 1.0000
# Epoch 248/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0048 - acc: 0.9995 - val_loss: 0.0047 - val_acc: 1.0000
# Epoch 249/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0048 - acc: 0.9995 - val_loss: 0.0048 - val_acc: 1.0000
# Epoch 250/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0048 - acc: 0.9995 - val_loss: 0.0048 - val_acc: 1.0000
# Epoch 251/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0047 - acc: 0.9995 - val_loss: 0.0048 - val_acc: 1.0000
# Epoch 252/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0048 - acc: 0.9995 - val_loss: 0.0048 - val_acc: 1.0000
# Epoch 253/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0047 - acc: 0.9995 - val_loss: 0.0047 - val_acc: 1.0000
# Epoch 254/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0047 - acc: 0.9995 - val_loss: 0.0046 - val_acc: 1.0000
# Epoch 255/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0047 - acc: 0.9995 - val_loss: 0.0046 - val_acc: 1.0000
# Epoch 256/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0047 - acc: 0.9995 - val_loss: 0.0047 - val_acc: 1.0000
# Epoch 257/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0046 - acc: 0.9995 - val_loss: 0.0047 - val_acc: 1.0000
# Epoch 258/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0046 - acc: 0.9995 - val_loss: 0.0047 - val_acc: 1.0000
# Epoch 259/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0046 - acc: 0.9995 - val_loss: 0.0046 - val_acc: 1.0000
# Epoch 260/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0046 - acc: 0.9995 - val_loss: 0.0046 - val_acc: 1.0000
# Epoch 261/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0046 - acc: 0.9995 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 262/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0045 - acc: 0.9995 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 263/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0045 - acc: 0.9995 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 264/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0045 - acc: 0.9995 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 265/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0045 - acc: 0.9995 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 266/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0045 - acc: 0.9995 - val_loss: 0.0044 - val_acc: 1.0000
# Epoch 267/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0045 - acc: 0.9995 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 268/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0044 - acc: 0.9995 - val_loss: 0.0044 - val_acc: 1.0000
# Epoch 269/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0044 - acc: 0.9995 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 270/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0044 - acc: 0.9995 - val_loss: 0.0044 - val_acc: 1.0000
# Epoch 271/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0044 - acc: 0.9995 - val_loss: 0.0044 - val_acc: 1.0000
# Epoch 272/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0044 - acc: 0.9995 - val_loss: 0.0043 - val_acc: 1.0000
# Epoch 273/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0044 - acc: 0.9995 - val_loss: 0.0044 - val_acc: 1.0000
# Epoch 274/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0044 - acc: 0.9995 - val_loss: 0.0043 - val_acc: 1.0000
# Epoch 275/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0043 - acc: 0.9995 - val_loss: 0.0043 - val_acc: 1.0000
# Epoch 276/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0043 - acc: 0.9995 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 277/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0043 - acc: 0.9995 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 278/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0043 - acc: 0.9995 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 279/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0043 - acc: 0.9995 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 280/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0042 - acc: 0.9995 - val_loss: 0.0043 - val_acc: 1.0000
# Epoch 281/400
# 2000/2000 [==============================] - 0s 5us/step - loss: 0.0042 - acc: 0.9995 - val_loss: 0.0043 - val_acc: 1.0000
# Epoch 282/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0042 - acc: 0.9995 - val_loss: 0.0043 - val_acc: 1.0000
# Epoch 283/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0042 - acc: 0.9995 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 284/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0042 - acc: 0.9995 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 285/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0042 - acc: 0.9995 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 286/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0042 - acc: 0.9995 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 287/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0041 - acc: 0.9995 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 288/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0041 - acc: 0.9995 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 289/400
# 2000/2000 [==============================] - 0s 13us/step - loss: 0.0041 - acc: 0.9995 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 290/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0041 - acc: 0.9995 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 291/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0041 - acc: 0.9995 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 292/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 293/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0040 - acc: 0.9995 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 294/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0041 - acc: 0.9995 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 295/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0040 - acc: 0.9995 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 296/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0040 - acc: 0.9995 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 297/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0040 - acc: 0.9995 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 298/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0040 - acc: 0.9995 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 299/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0040 - acc: 0.9995 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 300/400
# 2000/2000 [==============================] - 0s 5us/step - loss: 0.0040 - acc: 0.9995 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 301/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 302/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 303/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0038 - val_acc: 1.0000
# Epoch 304/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0038 - val_acc: 1.0000
# Epoch 305/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0038 - val_acc: 1.0000
# Epoch 306/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0038 - val_acc: 1.0000
# Epoch 307/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 308/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0038 - val_acc: 1.0000
# Epoch 309/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0039 - acc: 1.0000 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 310/400
# 2000/2000 [==============================] - 0s 10us/step - loss: 0.0039 - acc: 1.0000 - val_loss: 0.0038 - val_acc: 1.0000
# Epoch 311/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0038 - acc: 0.9995 - val_loss: 0.0038 - val_acc: 1.0000
# Epoch 312/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0038 - acc: 0.9995 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 313/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0038 - acc: 0.9995 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 314/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0038 - acc: 0.9995 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 315/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0037 - acc: 0.9995 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 316/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0037 - acc: 0.9995 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 317/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0037 - acc: 0.9995 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 318/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0037 - acc: 0.9995 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 319/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0037 - acc: 0.9995 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 320/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0037 - acc: 0.9995 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 321/400
# 2000/2000 [==============================] - 0s 5us/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 322/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 323/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 324/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 325/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 326/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0036 - acc: 0.9995 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 327/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0036 - acc: 0.9995 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 328/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0036 - acc: 0.9995 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 329/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0036 - acc: 0.9995 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 330/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0036 - acc: 0.9995 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 331/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0036 - acc: 0.9995 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 332/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0035 - acc: 0.9995 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 333/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0035 - acc: 0.9995 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 334/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0035 - acc: 0.9995 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 335/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 336/400
# 2000/2000 [==============================] - 0s 5us/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 337/400
# 2000/2000 [==============================] - 0s 11us/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 338/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0035 - acc: 0.9995 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 339/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0035 - acc: 0.9995 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 340/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0035 - acc: 0.9995 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 341/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 342/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 343/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 344/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 345/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 346/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 347/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 348/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 349/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 350/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 351/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 352/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 353/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 354/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 355/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 356/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 357/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 358/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 359/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 360/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 361/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 362/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 363/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 364/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 365/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 366/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 367/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 368/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 369/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 370/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 371/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 372/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 373/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 374/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 375/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 376/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 377/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 378/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 379/400
# 2000/2000 [==============================] - 0s 6us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 380/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 381/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 382/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 383/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 384/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 385/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 386/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 387/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 388/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 389/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 390/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 391/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 392/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 393/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 394/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 395/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000
# Epoch 396/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000
# Epoch 397/400
# 2000/2000 [==============================] - 0s 7us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000
# Epoch 398/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000
# Epoch 399/400
# 2000/2000 [==============================] - 0s 8us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000
# Epoch 400/400
# 2000/2000 [==============================] - 0s 9us/step - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000

# %%
prediction_values = model.predict_classes(X_test)

# %%
print(np.mean(results.history["val_acc"]))
# Out:
# 0.9893375000578165

# %%
# evaluate the model
scores = model.evaluate(X_train,y_train.T)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 2000/2000 [==============================] - 0s 18us/step
#
# acc: 100.00%

# %%
# summarize history for accuracy
plt.plot(results.history['acc'])
plt.plot(results.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='down right')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/legend.py:638: UserWarning: Unrecognized location "down right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   % (loc, '\n\t'.join(self.codes)))

# %%
# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

max_loss = np.max(results.history['loss'])
min_loss = np.min(results.history['loss'])
print("Maximum Loss : {:.4f}".format(max_loss))
print("")
print("Minimum Loss : {:.4f}".format(min_loss))
print("")
print("Loss difference : {:.4f}".format((max_loss - min_loss)))
# Out:
# Maximum Loss : 0.6878
#
# Minimum Loss : 0.0028
#
# Loss difference : 0.6849

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(12,7))
plt.scatter(X_train[:,0], X_train[:,1], c=y_train[0,:] ,cmap=cm.coolwarm)
plt.title('Training set')
plt.axis('equal');

# %%
plt.figure(figsize =(12,7))
plt.scatter(X_test[:,0], X_test[:,1], c=prediction_values[:,0], cmap=cm.coolwarm)
plt.title('Model predictions on our Training set')
plt.axis('equal');

# %%
# Input layer
weights0 = model.layers[0].get_weights()[0]
biases0 = model.layers[0].get_weights()[1]
print("Input layer weights",weights0.shape,":\n",weights0)
print("Input layer biases",biases0.shape,":\n",biases0)


# Output layer
weights1 = model.layers[1].get_weights()[0]
biases1 = model.layers[1].get_weights()[1]
print("\nOutput layer weights",weights1.shape,":\n",weights1)
print("Output layer biases",biases1.shape,":\n",biases1)
# Out:
# Input layer weights (2, 6) :
#  [[ 1.9465358  -0.17538781  0.12280516  0.17325395 -5.1113024   4.322896  ]
#  [-5.5063453  -0.10645939  0.12624834 -0.09363475  1.1054304   4.678166  ]]
# Input layer biases (6,) :
#  [-1.4364098  -0.23396432 -0.24781011 -0.27912357 -1.2378188  -1.3797681 ]
#
# Output layer weights (6, 1) :
#  [[-6.560309  ]
#  [ 0.14959942]
#  [ 0.15053725]
#  [ 0.27007234]
#  [-6.968896  ]
#  [-5.1357193 ]]
# Output layer biases (1,) :
#  [10.414007]

# %%
def sigmoid(z):
    return 1./(1+np.exp(-z))

def ReLU(z):
    return np.maximum(0,z)
  
z = np.linspace(-10,10,100)
plt.plot(z, sigmoid(z),'r', label = 'sigmoid')
plt.plot(z, ReLU(z),'b',label ='ReLU')
plt.legend(fontsize=12)

# %%
x1 = np.linspace(-2,2,50)
x2 = np.linspace(-2,2,50)
x3 = np.linspace(-1,1,50*50)

result = np.zeros((50*50,3)) 

out11 = np.zeros((50*50, 1))
out12 = np.zeros((50*50, 1))
out13 = np.zeros((50*50, 1))
out14 = np.zeros((50*50, 1))
out15 = np.zeros((50*50, 1))
out16 = np.zeros((50*50, 1))

out21 = np.zeros((50*50, 1))


for i in range(len(x1)):
  for j in range(len(x2 )):
    # Input layer
    n11 = x1[i] * weights0[0][0] + x2[j] * weights0[1][0] + biases0[0]
    a11 = ReLU(n11)

    n12 = x1[i] * weights0[0][1] + x2[j] * weights0[1][1] + biases0[1]
    a12 = ReLU(n12)
    
    n13 = x1[i] * weights0[0][2] + x2[j] * weights0[1][2] + biases0[2]
    a13 = ReLU(n13)
    
    n14 = x1[i] * weights0[0][3] + x2[j] * weights0[1][3] + biases0[3]
    a14 = ReLU(n14)
    
    n15 = x1[i] * weights0[0][4] + x2[j] * weights0[1][4] + biases0[4]
    a15 = ReLU(n15)
    
    n16 = x1[i] * weights0[0][5] + x2[j] * weights0[1][5] + biases0[5]
    a16 = ReLU(n16)
  
    # Output layer
    n21 = a11 * weights1[0][0] + a12 * weights1[1][0] + a13 * weights1[2][0] + a14 * weights1[3][0] + a15 * weights1[4][0] +a16 * weights1[5][0] + biases1[0]
    a21 = sigmoid(n21)

    
    result[i*50+j,0 ] = x1[i]
    result[i*50+j, 1] = x2[j]

    out11[i*50+j] = a11
    out12[i*50+j] = a12
    out13[i*50+j] = a13
    out14[i*50+j] = a14
    out15[i*50+j] = a15
    out16[i*50+j] = a16
    
    out21[i*50+j] = a21

# %%
plt.figure(figsize =(8,8))

# First neuron, input layer
plt.subplot(231)
plt.title('First neuron hidden layer 1')
plt.scatter(result[:, 0], result[:, 1], c= out11.reshape(-1), cmap=cm.coolwarm)

# Second neuron, input layer
plt.subplot(232)
plt.title('Second neuron hidden layer 1')
plt.scatter(result[:, 0], result[:, 1], c= out12.reshape(-1), cmap=cm.coolwarm)

# Third neuron, input layer
plt.subplot(233)
plt.title('Third neuron hidden layer 1')
plt.scatter(result[:, 0], result[:, 1], c= out13.reshape(-1), cmap=cm.coolwarm)

# Fourth neuron, input layer
plt.subplot(234)
plt.title('Fourth neuron hidden layer 1')
plt.scatter(result[:, 0], result[:, 1], c= out14.reshape(-1), cmap=cm.coolwarm)

# Fifth neuron, input layer
plt.subplot(235)
plt.title('Fifth neuron hidden layer 1')
plt.scatter(result[:, 0], result[:, 1], c= out15.reshape(-1), cmap=cm.coolwarm)

# Sixth neuron, input layer
plt.subplot(236)
plt.title('Sixth neuron hidden layer 1')
plt.scatter(result[:, 0], result[:, 1], c= out16.reshape(-1), cmap=cm.coolwarm)

# %%
# output layer
plt.title('Output layer')
plt.scatter(result[:, 0], result[:, 1], c= out21.reshape(-1), cmap=cm.coolwarm)

# %%
fig = plt.figure(figsize=(8, 5))
ax = plt.axes(projection='3d')
bar = ax.scatter3D(result[:, 0],result[:, 1],out11.reshape(-1), c=out11.reshape(-1), cmap=cm.coolwarm);
ax.view_init(30, 30)
ax.set_title('3D visualization of our neural network first layer first neuron')

fig = plt.figure(figsize=(8, 5))
ax = plt.axes(projection='3d')
bar = ax.scatter3D(result[:, 0],result[:, 1],out12.reshape(-1), c=out12.reshape(-1), cmap=cm.coolwarm);
ax.view_init(30, 30)
ax.set_title('3D visualization of our neural network first layer second neuron')

fig = plt.figure(figsize=(8, 5))
ax = plt.axes(projection='3d')
bar = ax.scatter3D(result[:, 0],result[:, 1],out13.reshape(-1), c=out13.reshape(-1), cmap=cm.coolwarm);
ax.view_init(30, 30)
ax.set_title('3D visualization of our neural network first layer third neuron')

fig = plt.figure(figsize=(8, 5))
ax = plt.axes(projection='3d')
bar = ax.scatter3D(result[:, 0],result[:, 1],out14.reshape(-1), c=out14.reshape(-1), cmap=cm.coolwarm);
ax.view_init(30, 30)
ax.set_title('3D visualization of our neural network first layer fourth neuron')

fig = plt.figure(figsize=(8, 5))
ax = plt.axes(projection='3d')
bar = ax.scatter3D(result[:, 0],result[:, 1],out14.reshape(-1), c=out14.reshape(-1), cmap=cm.coolwarm);
ax.view_init(30, 30)
ax.set_title('3D visualization of our neural network first layer fifth neuron')

fig = plt.figure(figsize=(8, 5))
ax = plt.axes(projection='3d')
bar = ax.scatter3D(result[:, 0],result[:, 1],out15.reshape(-1), c=out15.reshape(-1), cmap=cm.coolwarm);
ax.view_init(30, 30)
ax.set_title('3D visualization of our neural network first layer sixth neuron')
# Out:
# Text(0.5,0.92,'3D visualization of our neural network first layer sixth neuron')

# %%
fig = plt.figure(figsize=(8, 5))
ax = plt.axes(projection='3d')
bar = ax.scatter3D(result[:, 0],result[:, 1],out21.reshape(-1), c=out21.reshape(-1), cmap=cm.coolwarm);
ax.view_init(30,-45)
ax.set_title('3D visualization of our neural network output layer')
# Out:
# Text(0.5,0.92,'3D visualization of our neural network output layer')
